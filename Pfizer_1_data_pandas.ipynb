# %% [markdown]
# <a href="https://colab.research.google.com/github/V-arshaSharma/Movie-Correlation/blob/main/Pfizer_1_data_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import numpy as np
import pandas as pd

# %%
# download DataFrame
# !gdown 1Etdl87T1Ab711XGxIXQID0wHxi7YMLRj
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Etdl87T1Ab711XGxIXQID0wHxi7YMLRj
# To: /content/Pfizer_1.csv
# 100% 1.51k/1.51k [00:00<00:00, 8.52MB/s]

# %%
# read the csv into a DataFrame
df = pd.read_csv("Pfizer_1.csv")

# %%
df
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
df.shape
# Out:
# (18, 15)

# %%
# in above data null values is here just like real world data
#  pivort is converting row into cloumns and vice versa basically its rotating
# melt function

pd.melt(df, id_vars=["Date",	"Drug_Name",	"Parameter"] )
# Out:
#            Date                Drug_Name    Parameter  variable  value
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00   23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00   12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00    NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00    NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00   24.0
# ..          ...                      ...          ...       ...    ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00   14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00   23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00   28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00   24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00   15.0
#
# [216 rows x 5 columns]

# %%
# rename columns
df2 = pd.melt(df, id_vars=["Date",	"Drug_Name",	"Parameter"]).rename(columns={'variable':'time', 'value' : 'reading'})
df2
# Out:
#            Date                Drug_Name    Parameter      time  reading
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00     23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00     12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00      NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00      NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00     24.0
# ..          ...                      ...          ...       ...      ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00     14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00     23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00     28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00     24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00     15.0
#
# [216 rows x 5 columns]

# %%
# pivoting pressure and temp values
df3 = pd.pivot(df2,['Date',	'Drug_Name', 'time'],columns = 'Parameter', values= 'reading')
df3
# Out:
# <ipython-input-34-4dda232d8266>:2: FutureWarning: In a future version of pandas all arguments of pivot except for the argument 'data' will be keyword-only.
#   df3 = pd.pivot(df2,['Date',	'Drug_Name', 'time'],columns = 'Parameter', values= 'reading')
# Parameter                                    Pressure  Temperature
# Date       Drug_Name               time
# 15-10-2020 diltiazem hydrochloride 10:30:00      18.0         20.0
#                                    11:30:00      19.0         20.0
#                                    12:30:00      20.0         21.0
#                                    1:30:00       12.0         23.0
#                                    2:30:00       13.0         22.0
# ...                                               ...          ...
# 17-10-2020 ketamine hydrochloride  5:30:00       11.0         17.0
#                                    6:30:00       12.0         18.0
#                                    7:30:00       12.0         19.0
# ...

# %%
df3.reset_index()
# Out:
# Parameter        Date                Drug_Name      time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 20.0
# 2                 21.0
# 3                 23.0
# 4                 22.0
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 108 entries, ('15-10-2020', 'diltiazem hydrochloride', '10:30:00') to ('17-10-2020', 'ketamine hydrochloride', '9:30:00')
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pressure     95 non-null     float64
#  1   Temperature  95 non-null     float64
# dtypes: float64(2)
# memory usage: 2.8+ KB

# %%
# lets make a series
s1 = pd.Series([1,2,None,4,5,np.nan])
s1
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# 5    NaN
# dtype: float64

# %%
s1.isna()  #isna fxn gives bolean values
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
-s1.isna() #titde - will inverse
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
d1= pd.DataFrame([[10,20],[None,20], [30,np.nan]])
d1
# Out:
#       0     1
# 0  10.0  20.0
# 1   NaN  20.0
# 2  30.0   NaN

# %%
d1.isna()
# Out:
#        0      1
# 0  False  False
# 1   True  False
# 2  False   True

# %%
d1.isnull() #isna and isnull is same like isna is alias of isnull and perferable is isnull fxn
# Out:
#        0      1
# 0  False  False
# 1   True  False
# 2  False   True

# %% [markdown]
# Hiding all the NA values in pressure column of df3

# %%
mask = df3['Pressure'].isna()
mask
# Out:
# Date        Drug_Name                time
# 15-10-2020  diltiazem hydrochloride  10:30:00    False
#                                      11:30:00    False
#                                      12:30:00    False
#                                      1:30:00     False
#                                      2:30:00     False
#                                                  ...
# 17-10-2020  ketamine hydrochloride   5:30:00     False
#                                      6:30:00     False
#                                      7:30:00     False
#                                      8:30:00     False
#                                      9:30:00     False
# Name: Pressure, Length: 108, dtype: bool

# %%
mask = -df3['Pressure'].isna()
mask
# Out:
# Date        Drug_Name                time
# 15-10-2020  diltiazem hydrochloride  10:30:00    True
#                                      11:30:00    True
#                                      12:30:00    True
#                                      1:30:00     True
#                                      2:30:00     True
#                                                  ...
# 17-10-2020  ketamine hydrochloride   5:30:00     True
#                                      6:30:00     True
#                                      7:30:00     True
#                                      8:30:00     True
#                                      9:30:00     True
# Name: Pressure, Length: 108, dtype: bool

# %%
df3[mask] #whenever applying mask , df3[] is also working
# Out:
# Parameter                                    Pressure  Temperature
# Date       Drug_Name               time
# 15-10-2020 diltiazem hydrochloride 10:30:00      18.0         20.0
#                                    11:30:00      19.0         20.0
#                                    12:30:00      20.0         21.0
#                                    1:30:00       12.0         23.0
#                                    2:30:00       13.0         22.0
# ...                                               ...          ...
# 17-10-2020 ketamine hydrochloride  5:30:00       11.0         17.0
#                                    6:30:00       12.0         18.0
#                                    7:30:00       12.0         19.0
#                                    8:30:00       11.0         20.0
#                                    9:30:00       12.0         21.0
#
# [95 rows x 2 columns]

# %%
df3.loc[mask]
# Out:
# Parameter                                    Pressure  Temperature
# Date       Drug_Name               time
# 15-10-2020 diltiazem hydrochloride 10:30:00      18.0         20.0
#                                    11:30:00      19.0         20.0
#                                    12:30:00      20.0         21.0
#                                    1:30:00       12.0         23.0
#                                    2:30:00       13.0         22.0
# ...                                               ...          ...
# 17-10-2020 ketamine hydrochloride  5:30:00       11.0         17.0
#                                    6:30:00       12.0         18.0
#                                    7:30:00       12.0         19.0
#                                    8:30:00       11.0         20.0
#                                    9:30:00       12.0         21.0
#
# [95 rows x 2 columns]

# %% [markdown]
# Another data Superstore in xl sheet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# we need to covert into csv so by downloading option we can downld as csv
# get store dataframe
store = pd.read_csv('/content/sample_-_superstore (1).xlsm - Orders.csv')

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
# many columns lest pull out some of them
s1 = store[['Ship Mode','Category', 'Quantity']].rename(columns = {'Ship Mode' :'Ship_mode' })
s1.head()
# Out:
#         Ship_mode         Category  Quantity
# 0    Second Class        Furniture         2
# 1    Second Class        Furniture         3
# 2    Second Class  Office Supplies         2
# 3  Standard Class        Furniture         5
# 4  Standard Class  Office Supplies         2

# %%
s1.query('Ship_mode == "Second Class" and Category == "Technology"')
# Out:
#          Ship_mode    Category  Quantity
# 19    Second Class  Technology         3
# 26    Second Class  Technology         3
# 161   Second Class  Technology         2
# 181   Second Class  Technology         7
# 182   Second Class  Technology         4
# ...            ...         ...       ...
# 9891  Second Class  Technology         7
# 9892  Second Class  Technology         5
# 9949  Second Class  Technology         3
# 9950  Second Class  Technology         1
# 9960  Second Class  Technology         1
#
# [366 rows x 3 columns]

# %%
# apply filter here
s2 = s1.query('Ship_mode == "Second Class" and Category == "Technology"') ["Quantity"].sum( )
s2
# Out:
# 1374

# %%
# Null values
# create one dumy dataframe
lst = [ [1,None,3], [11, np.NaN, 13], [None, None , None]]

# %%
df = pd.DataFrame(lst)
df
# Out:
#       0   1     2
# 0   1.0 NaN   3.0
# 1  11.0 NaN  13.0
# 2   NaN NaN   NaN

# %%
df.dropna() #drop all the row we can do
# Out:
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []

# %%
df.dropna(axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
df.dropna(axis = 0) # it will drop nan value along row
# Out:
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []

# %%
df.dropna(axis = 1) # it will drop every columns with nan values
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
# leave all the row having one or more null values
df.dropna(axis = 0, thresh = 2) #threhold is the number of non nan value that you require in every row
# when we go along axis 0, it will drop rows
# thresh = 2 means it will tolerate each row atleast having 2 nan values
#it will drop the row having more then 2 nan values
# Out:
#       0   1     2
# 0   1.0 NaN   3.0
# 1  11.0 NaN  13.0

# %%
df.dropna(axis = 0, thresh = 1)
# Out:
#       0   1     2
# 0   1.0 NaN   3.0
# 1  11.0 NaN  13.0

# %%
# drop every vale is null
df.dropna(axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
# string methods on pandas dataframe
s1.info
# Out:
# <bound method DataFrame.info of            Ship_mode         Category  Quantity
# 0       Second Class        Furniture         2
# 1       Second Class        Furniture         3
# 2       Second Class  Office Supplies         2
# 3     Standard Class        Furniture         5
# 4     Standard Class  Office Supplies         2
# ...              ...              ...       ...
# 9989    Second Class        Furniture         3
# 9990  Standard Class        Furniture         2
# 9991  Standard Class       Technology         2
# 9992  Standard Class  Office Supplies         4
# 9993    Second Class  Office Supplies         2
#
# [9994 rows x 3 columns]>

# %%
# shipmode into string
s2 = s1["Ship_mode"].astype(dtype = 'string') #we neeed to give full word string not str here in python we can use str

# %%
s2
# Out:
# 0         Second Class
# 1         Second Class
# 2         Second Class
# 3       Standard Class
# 4       Standard Class
#              ...
# 9989      Second Class
# 9990    Standard Class
# 9991    Standard Class
# 9992    Standard Class
# 9993      Second Class
# Name: Ship_mode, Length: 9994, dtype: string

# %%
# string methods str.upper(), str.lower(), str.startswith(), endswith(), str.split()
s1["Category"].str.lower()
# Out:
# 0             furniture
# 1             furniture
# 2       office supplies
# 3             furniture
# 4       office supplies
#              ...
# 9989          furniture
# 9990          furniture
# 9991         technology
# 9992    office supplies
# 9993    office supplies
# Name: Category, Length: 9994, dtype: object

# %%
s1["Category"].str.split()
# Out:
# 0              [Furniture]
# 1              [Furniture]
# 2       [Office, Supplies]
# 3              [Furniture]
# 4       [Office, Supplies]
#                ...
# 9989           [Furniture]
# 9990           [Furniture]
# 9991          [Technology]
# 9992    [Office, Supplies]
# 9993    [Office, Supplies]
# Name: Category, Length: 9994, dtype: object

# %%
s1["Category"].str.split(expand = False)
# Out:
# 0              [Furniture]
# 1              [Furniture]
# 2       [Office, Supplies]
# 3              [Furniture]
# 4       [Office, Supplies]
#                ...
# 9989           [Furniture]
# 9990           [Furniture]
# 9991          [Technology]
# 9992    [Office, Supplies]
# 9993    [Office, Supplies]
# Name: Category, Length: 9994, dtype: object

# %%
s1["Category"].str.split(expand = True)
# Out:
#                0         1
# 0      Furniture      None
# 1      Furniture      None
# 2         Office  Supplies
# 3      Furniture      None
# 4         Office  Supplies
# ...          ...       ...
# 9989   Furniture      None
# 9990   Furniture      None
# 9991  Technology      None
# 9992      Office  Supplies
# 9993      Office  Supplies
#
# [9994 rows x 2 columns]

# %% [markdown]
# DateTime Datatype

# %%
store
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
store.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# convert datatype
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
store["Order Date"] = pd.to_datetime(store["Order Date"] )

# %%
store.info() #convert datetype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
store["Order Date"].dt.day #no brackets becoz its not function its property , day is property od date function we can also extract month, year
# Out:
# 0        8
# 1        8
# 2       12
# 3       11
# 4       11
#         ..
# 9989    21
# 9990    26
# 9991    26
# 9992    26
# 9993     4
# Name: Order Date, Length: 9994, dtype: int64

# %%
store["Order Date"].dt.month
# Out:
# 0       11
# 1       11
# 2        6
# 3       10
# 4       10
#         ..
# 9989     1
# 9990     2
# 9991     2
# 9992     2
# 9993     5
# Name: Order Date, Length: 9994, dtype: int64

# %%
store["Order Date"].dt.year
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2015
# 4       2015
#         ...
# 9989    2014
# 9990    2017
# 9991    2017
# 9992    2017
# 9993    2017
# Name: Order Date, Length: 9994, dtype: int64

# %%
store["Year"] = store["Order Date"].dt.day #adding new colum year

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
store.groupby("Year")["Quantity"].aggregate(["sum"]) #find the sum or  of order quantity by year
# Out:
#        sum
# Year
# 1     1329
# 2     1486
# 3     1355
# 4     1068
# 5     1386
# 6     1071
# 7     1102
# 8     1372
# 9     1272
# 10    1117
# 11    1358
# 12    1320
# 13    1322
# 14    1307
# 15    1017
# 16     976
# 17    1340
# 18    1223
# 19    1266
# 20    1436
# 21    1496
# 22    1086
# 23    1392
# 24    1166
# 25    1269
# 26    1420
# 27    1055
# 28    1098
# 29     877
# 30    1142
# 31     749

# %%
store.groupby("Year")["Profit"].aggregate(["sum"]) #profit they had evey year
# Out:
#              sum
# Year
# 1     17006.7750
# 2     19441.0907
# 3      7090.5233
# 4      6873.6366
# 5      7498.2938
# 6      7489.6978
# 7      3773.0900
# 8     12088.5279
# 9      9917.1628
# 10     5315.2909
# 11     6871.5327
# 12     5437.6936
# 13     7528.8836
# 14    12841.0063
# 15     5421.5608
# 16    12468.5300
# 17    17155.3654
# 18     6279.7063
# 19     5605.1418
# 20    10074.3612
# 21    16681.1567
# 22     9378.4818
# 23    20096.6111
# 24    11855.6134
# 25     2029.3777
# 26     7083.9832
# 27     7019.6499
# 28     4868.1548
# 29     5418.8078
# 30     5865.8076
# 31     9921.5072

# %%
def sqr(x):
  return x**2
a = [ 1,2,3,4,5]
b = list(map(sqr,a))
print(b)
s = pd.Series(a)
s.apply(sqr)
# Out:
# [1, 4, 9, 16, 25]
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# dtype: int64

# %%
s.apply(lambda x:x**2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# dtype: int64
